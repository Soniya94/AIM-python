# %%
a=5
b=3

# %%
a//b
# Out:
# 1

# %%
a%b
# Out:
# 2

# %%
a**2
# Out:
# 25

# %%
a = 3.5
print(int(a))
# Out:
# 3

# %%
ab = 10
cd =(float(ab))
cd
# Out:
# 10.0

# %%
type(ab)
# Out:
# int

# %%
type (cd)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
num = 2+3j
num
# Out:
# (2+3j)

# %%
type(num)
# Out:
# complex

# %%
# int(data)

# %%
data = (complex(2,3))

# %%
data
# Out:
# (2+3j)

# %%
type(a==b)
# Out:
# bool

# %%
a = 10
b = 20

# %%
a == b
# Out:
# False

# %%
a//b
# Out:
# 0

# %%
a != b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
import math

# %%
x = -22.5
math.fabs(x)
# Out:
# 22.5

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.gcd(3,6,9,12)
# Out:
# 3

# %%
math.ceil(44.9)
# Out:
# 45

# %%
math.floor(44.9)
# Out:
# 44

# %%
math.isfinite(22)
# Out:
# True

# %%
user = 640
capacity = 129

# %%
result = min(user, capacity)
result
# Out:
# 129

# %%
round(22.456, 2)
# Out:
# 22.46
