# %%
data1 = "Hello"

# %%
type (data1)
# Out:
# str

# %%
str
# Out:
# str

# %%
data2 = 'hello'

# %%
str
# Out:
# str

# %%
# I`m a boy

# %%
data3 = "I`m a boy"

# %%
data4 = "I am a boy"
data4 = data4.replace("I am a boy", "Male")
print(data4)
# Out:
# Male

# %%
data4 = {"I am a boy": "Male"}
print(data4)
# Out:
# {'I am a boy': 'Male'}

# %%
data4
# Out:
# {'I am a boy': 'Male'}

# %%
data3 = "python\n"
data3
# Out:
# 'python\n'

# %%
data3 = "python\b"
data3
# Out:
# 'python\x08'

# %%
data3 = "python\t"
data3
# Out:
# 'python\t'

# %%
data3 = "python\\"
data3
# Out:
# 'python\\'

# %%
data3 = "python\'"
data3
# Out:
# "python'"

# %%
data3 = "python\""
data3
# Out:
# 'python"'

# %%
print(data3)
# Out:
# python"

# %%
fname = "Soniya"
lname = "Pariyar"

fullname = fname + " " +lname
fullname
# Out:
# 'Soniya Pariyar'

# %%
fname*3
# Out:
# 'SoniyaSoniyaSoniya'

# %%
#slicing

# %%
data_="Python"

# %%
data_[5]
# Out:
# 'n'

# %%
data_[-2]
# Out:
# 'o'

# %%
data_[1:5] #ytho
# Out:
# 'ytho'

# %%
#[start:end] Syntax

# %%
data = "Lorem Ipsum is simply dummy text of the printing and typesetting industry."

# %%
data[3:25:2]

#[start:end:step]
# Out:
# 'e pu ssml u'

# %%
data2 ="pythondata"

# %%
data[1:8:2]
# Out:
# 'oe p'

# %%
len(data)
# Out:
# 74

# %%
data
# Out:
# 'Lorem Ipsum is simply dummy text of the printing and typesetting industry.'

# %%
data.upper()
# Out:
# 'LOREM IPSUM IS SIMPLY DUMMY TEXT OF THE PRINTING AND TYPESETTING INDUSTRY.'

# %%
data.lower()
# Out:
# 'lorem ipsum is simply dummy text of the printing and typesetting industry.'

# %%
data.title()
# Out:
# 'Lorem Ipsum Is Simply Dummy Text Of The Printing And Typesetting Industry.'

# %%
text = "       Hello World         "
text.strip()
# Out:
# 'Hello World'

# %%
text = "#####Python#####"
text.strip("#")
# Out:
# 'Python'

# %%
text = "I like Python"
text.replace("I", "you")
# Out:
# 'you like Python'

# %%
text = "apple, mango, orange"
print(type(text))
data_text = text.split('a')
data_text
# Out:
# <class 'str'>
# ['', 'pple, m', 'ngo, or', 'nge']

# %%
type(text)
# Out:
# str

# %%
letters = ["P","Y","T","H","O","N"]
print("".join(letters))
# Out:
# PYTHON
